# %%
import numpy as np
from scipy import signal
import pandas as pd
import datetime
from matplotlib import pyplot as plt
import random
import scipy.stats as stats
import matplotlib.mlab as mlab 
import math

plt.rcParams['figure.figsize'] = (4, 3)

plt.subplot(1,2,1)
mu = 0
sigma = np.sqrt(1/10.639)
u = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
score = []
with open("Template C_normal_p.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*100 for i in score]        
plt.hist(score, normed =1)
plt.plot(u, stats.norm.pdf(u, mu, sigma)) 
plt.xlabel(r'$\sqrt{n}(\hat{\theta}_n-\theta^*$)',fontsize =11) 
plt.title('Pearson') 

plt.subplot(1,2,2)
mu = 0
sigma = np.sqrt(0.7881/(2.8196**2))
u = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
score = []
with open("Template C_normal_rank.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*100 for i in score]        
plt.hist(score, normed =1)
plt.plot(u, stats.norm.pdf(u, mu, sigma)) 
plt.xlabel(r'$\sqrt{n}(\hat{\theta}_n-\theta^*$)',fontsize =11) 
plt.title('Spearman')  

plt.tight_layout()
plt.show()

# %%
plt.rcParams['figure.figsize'] = (4, 3)

plt.subplot(1,2,1)
mu = 0
sigma = np.sqrt(3/10.639)
u = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
score = []
with open("Template C_t3_p.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*100 for i in score]        
plt.hist(score, normed =1)
plt.plot(u, stats.norm.pdf(u, mu, sigma)) 
plt.xlabel(r'$\sqrt{n}(\hat{\theta}_n-\theta^*$)',fontsize =11) 
plt.title('Pearson') 

plt.subplot(1,2,2)
mu = 0
sigma = np.sqrt(0.7486/(2.3081**2))
u = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
score = []
with open("Template C_t3_rank.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*100 for i in score]        
plt.hist(score, normed =1)
plt.plot(u, stats.norm.pdf(u, mu, sigma)) 
plt.xlabel(r'$\sqrt{n}(\hat{\theta}_n-\theta^*$)',fontsize =11) 
plt.title('Spearman')  

plt.tight_layout()
plt.show()

# %%
plt.rcParams['figure.figsize'] = (4, 3)

plt.subplot(1,2,1)
score = []
with open("Template C_cauchy_p.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*100 for i in score]        
plt.hist(score, normed =1)
plt.xlabel(r'$\sqrt{n}(\hat{\theta}_n-\theta^*$)',fontsize =11) 
plt.title('Pearson') 

plt.subplot(1,2,2)
mu = 0
sigma = np.sqrt(0.5416/(1.5960**2))
u = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
score = []
with open("Template C_cauchy_rank.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*100 for i in score]        
plt.hist(score, normed =1)
plt.plot(u, stats.norm.pdf(u, mu, sigma)) 
plt.xlabel(r'$\sqrt{n}(\hat{\theta}_n-\theta^*$)',fontsize =11) 
plt.title('Spearman')  

plt.tight_layout()
plt.show()
